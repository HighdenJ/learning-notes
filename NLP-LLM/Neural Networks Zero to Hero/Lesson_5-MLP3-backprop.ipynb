# %% [markdown]
# ### Lecture 5: Building makemore Part 4: Becoming a Backprop Ninja
#
# [Youtube video lecture](https://www.youtube.com/watch?v=q8SA3rM6ckI)
# [makemore repo](https://github.com/karpathy/makemore)
# [Juputer notebook files](https://github.com/karpathy/nn-zero-to-hero/blob/master/lectures/makemore/makemore_part4_backprop.ipynb)
#
# Video upload date: Oct 12, 2022 (length: 1 hr 55 min)
# Watched on: Nov 26, 2025    ### I admit I didn't finish. Sry, Andrej.
# Reproduced on:   ### Thanks, I'm gonna pass :)
#
# Content:
# - check torch calculated gradient with handwritten gradient calculation
