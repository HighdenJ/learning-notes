# %% [markdown]
# ### Karpathy: Deep Dive into LLMs like ChatGPT
#
# [Youtube video lecture](https://www.youtube.com/watch?v=7xTGNNLPyMI)
#
#
# Video upload date: Feb 6, 2025 (length: 3 hr 31 min)
# Watched on: Nov 30, 2025
#
#
# Content:
# - [FineWeb dataset](https://huggingface.co/spaces/HuggingFaceFW/blogpost-fineweb-v1)
# - [GPT2 reproduction](https://github.com/karpathy/llm.c/discussions/677)
#
# ---

# %% [markdown]
# ### Hallucination mitigation
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Distribute computation to more tokens
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Reinforcement Learning
#
# The third (and last) stage of model training (after pre-training, fine-tuning).
# Given problem and answer, model practices.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Training a model to imitate human giving scores.
#
# ![image-3.png](attachment:image-3.png)
