# %% [markdown]
# ### [Lesson 1](https://www.youtube.com/watch?v=VMj-3S1tku0)
# #### The spelled-out intro to neural networks and backpropagation: building micrograd
#
# Video upload date: Aug 17, 2022 (length: 2h25m)
# Watched on: Nov, 11, 2025 (57m43s)
#
# Content:
# - Backpropagation

# %% [markdown]
# intuitively understanding of what derivative is?
